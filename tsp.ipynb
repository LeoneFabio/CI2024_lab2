# %% [markdown]
# # Travelling Salesman Problem

# %% [markdown]
# ## Global code

# %%
import pandas as pd
import numpy as np
from geopy.distance import geodesic
from itertools import combinations
import networkx as nx
import random
from dataclasses import dataclass

# %%
# Load cities data
CITIES = pd.read_csv('cities/italy.csv', header=None, names=['name', 'lat', 'lon'])

# Create distance matrix
DIST_MATRIX = np.zeros((len(CITIES), len(CITIES)))
for c1, c2 in combinations(CITIES.itertuples(), 2):
    DIST_MATRIX[c1.Index, c2.Index] = DIST_MATRIX[c2.Index, c1.Index] = geodesic(
        (c1.lat, c1.lon), (c2.lat, c2.lon)
    ).km

# %% [markdown]
# ## Helper Functions

# %%
def print_tour(path, distance_matrix, cities):
    total_distance = 0.0
    for i in range(len(path) - 1):
        city_from = path[i]
        city_to = path[i + 1]
        distance = distance_matrix[city_from][city_to]
        total_distance += distance
        
        print(f"step {i+1}: {cities.at[city_from,'name']} -> {cities.at[city_to,'name']} ({distance:.2f}km)")

    print(f"\nResult: Found a path of {len(path) - 1} steps, total length {total_distance:.2f}km")

# %% [markdown]
# ## Greedy Approaches
# In the follow three different algorithms based on a greedy approach are presented.

# %% [markdown]
# ### Minimum Spanning Tree (MST)

# %%
# Function to compute TSP path using Minimum Spanning Tree
def mst_tsp(distance_matrix):
    # Create a graph from distance matrix
    G = nx.Graph()
    num_cities = len(distance_matrix)
    
    # Add edges to the graph with distances as weights
    for i in range(num_cities):
        for j in range(i + 1, num_cities):
            G.add_edge(i, j, weight=distance_matrix[i][j])
    
    # Generate MST
    mst = nx.minimum_spanning_tree(G, weight='weight')
    
    # Get a preorder traversal of the MST (DFS)
    preorder_nodes = list(nx.dfs_preorder_nodes(mst, source=0))
    
    # Generate TSP path by visiting nodes in preorder
    tsp_tour = preorder_nodes + [preorder_nodes[0]]  # Return to starting city
    
    return tsp_tour

# %% [markdown]
# #### Run MST

# %%
# Run MST-based TSP approximation
tsp_tour = mst_tsp(DIST_MATRIX)

# Print each step of the tour and calculate the total distance
print("MST-based TSP Tour\n")
print_tour(tsp_tour, DIST_MATRIX, CITIES)
# Out:
# MST-based TSP Tour
#
# step 1: Abakan -> Krasnoyarsk (276.58km)
# step 2: Krasnoyarsk -> Achinsk (161.71km)
# step 3: Achinsk -> Bratsk (693.41km)
# step 4: Bratsk -> Angarsk (439.00km)
# step 5: Angarsk -> Irkutsk (34.88km)
# step 6: Irkutsk -> Ulan‐Ude (238.28km)
# step 7: Ulan‐Ude -> Chita (402.25km)
# step 8: Chita -> Blagoveshchensk (1002.31km)
# step 9: Blagoveshchensk -> Khabarovsk (588.32km)
# step 10: Khabarovsk -> Komsomolsk‐na‐Amure (274.21km)
# step 11: Komsomolsk‐na‐Amure -> Yuzhno‐Sakhalinsk (582.17km)
# step 12: Yuzhno‐Sakhalinsk -> Ussuriysk (909.51km)
# step 13: Ussuriysk -> Artyom (50.78km)
# step 14: Artyom -> Vladivostok (34.21km)
# step 15: Vladivostok -> Nakhodka (87.36km)
# step 16: Nakhodka -> Yakutsk (2146.61km)
# step 17: Yakutsk -> Magadan (1173.79km)
# step 18: Magadan -> Petropavlovsk‐Kamchatskiy (875.16km)
# step 19: Petropavlovsk‐Kamchatskiy -> Novokuznetsk (4553.60km)
# step 20: Novokuznetsk -> Prokopyevsk (30.63km)
# step 21: Prokopyevsk -> Leninsk‐Kuznetskiy (91.87km)
# step 22: Leninsk‐Kuznetskiy -> Kemerovo (74.76km)
# step 23: Kemerovo -> Tomsk (147.60km)
# step 24: Tomsk -> Seversk (14.97km)
# step 25: Seversk -> Biysk (454.70km)
# step 26: Biysk -> Barnaul (132.82km)
# step 27: Barnaul -> Novosibirsk (194.50km)
# step 28: Novosibirsk -> Omsk (609.10km)
# step 29: Omsk -> Tobolsk (475.40km)
# step 30: Tobolsk -> Tyumen (200.98km)
# step 31: Tyumen -> Kurgan (189.69km)
# step 32: Kurgan -> Kamensk‐Uralskiy (237.85km)
# step 33: Kamensk‐Uralskiy -> Yekaterinburg (95.20km)
# step 34: Yekaterinburg -> Pervouralsk (40.19km)
# step 35: Pervouralsk -> Nizhniy Tagil (112.49km)
# step 36: Nizhniy Tagil -> Perm (220.37km)
# step 37: Perm -> Berezniki (159.92km)
# step 38: Berezniki -> Chelyabinsk (551.12km)
# step 39: Chelyabinsk -> Kopeysk (14.72km)
# step 40: Kopeysk -> Miass (100.44km)
# step 41: Miass -> Zlatoust (33.88km)
# step 42: Zlatoust -> Magnitogorsk (199.76km)
# step 43: Magnitogorsk -> Sterlitamak (201.63km)
# step 44: Sterlitamak -> Salavat (29.01km)
# step 45: Salavat -> Orenberg (185.10km)
# step 46: Orenberg -> Orenburg (0.37km)
# step 47: Orenburg -> Novotroitsk (232.42km)
# step 48: Novotroitsk -> Orsk (21.66km)
# step 49: Orsk -> Ufa (433.61km)
# step 50: Ufa -> Oktyabrskiy (170.17km)
# step 51: Oktyabrskiy -> Almetyevsk (88.27km)
# step 52: Almetyevsk -> Naberezhnye Chelny (87.95km)
# step 53: Naberezhnye Chelny -> Nizhnekamsk (31.95km)
# step 54: Nizhnekamsk -> Kazan (169.59km)
# step 55: Kazan -> Novocheboksarsk (109.88km)
# step 56: Novocheboksarsk -> Cheboksary (15.59km)
# step 57: Cheboksary -> Yoshkar‐Ola (68.49km)
# step 58: Yoshkar‐Ola -> Kirov (243.07km)
# step 59: Kirov -> Syktyvkar (347.95km)
# step 60: Syktyvkar -> Ulyanovsk (829.69km)
# step 61: Ulyanovsk -> Dimitrovgrad (75.41km)
# step 62: Dimitrovgrad -> Tolyatti (85.74km)
# step 63: Tolyatti -> Novokuybyshevsk (49.80km)
# step 64: Novokuybyshevsk -> Samara (17.80km)
# step 65: Samara -> Syzran (112.35km)
# step 66: Syzran -> Balakovo (135.20km)
# step 67: Balakovo -> Engels (128.88km)
# step 68: Engels -> Saratov (9.98km)
# step 69: Saratov -> Penza (194.46km)
# step 70: Penza -> Saransk (109.72km)
# step 71: Saransk -> Arzamas (159.69km)
# step 72: Arzamas -> Dzerzhinsk (98.38km)
# step 73: Dzerzhinsk -> Nizhny Novgorod (34.91km)
# step 74: Nizhny Novgorod -> Murom (148.83km)
# step 75: Murom -> Kovrov (98.78km)
# step 76: Kovrov -> Vladimir (62.07km)
# step 77: Vladimir -> Orekhovo‐Zuevo (95.53km)
# step 78: Orekhovo‐Zuevo -> Noginsk (34.00km)
# step 79: Noginsk -> Elektrostal (6.68km)
# step 80: Elektrostal -> Shchyolkovo (29.02km)
# step 81: Shchyolkovo -> Balashikha (11.97km)
# step 82: Balashikha -> Zheleznodorozhnyy (6.96km)
# step 83: Zheleznodorozhnyy -> Lyubertsy (11.95km)
# step 84: Lyubertsy -> Zhukovskiy (26.33km)
# step 85: Zhukovskiy -> Kolomna (62.21km)
# step 86: Kolomna -> Ryazan (80.15km)
# step 87: Ryazan -> Korolyov (189.30km)
# step 88: Korolyov -> Mytishchi (5.74km)
# step 89: Mytishchi -> Khimki (18.28km)
# step 90: Khimki -> Zelenograd (10.91km)
# step 91: Zelenograd -> Tver (134.04km)
# step 92: Tver -> Moscow (163.52km)
# step 93: Moscow -> Odintsovo (22.57km)
# step 94: Odintsovo -> Podolsk (32.00km)
# step 95: Podolsk -> Serpukhov (56.28km)
# step 96: Serpukhov -> Obninsk (54.96km)
# step 97: Obninsk -> Kaluga (66.06km)
# step 98: Kaluga -> Tula (94.96km)
# step 99: Tula -> Novomoskovsk (41.70km)
# step 100: Novomoskovsk -> Yelets (166.95km)
# step 101: Yelets -> Lipetsk (75.22km)
# step 102: Lipetsk -> Voronezh (103.13km)
# step 103: Voronezh -> Staryy Oskol (109.10km)
# step 104: Staryy Oskol -> Belgorod (116.64km)
# step 105: Belgorod -> Kursk (127.70km)
# step 106: Kursk -> Oryol (138.18km)
# step 107: Oryol -> Bryansk (115.74km)
# step 108: Bryansk -> Smolensk (230.10km)
# step 109: Smolensk -> Velikie Luki (198.09km)
# step 110: Velikie Luki -> Pskov (212.88km)
# step 111: Pskov -> Velikiy Novgorod (189.82km)
# step 112: Velikiy Novgorod -> Kolpino (142.44km)
# step 113: Kolpino -> Saint Petersburg (25.47km)
# step 114: Saint Petersburg -> Petrozavodsk (302.88km)
# step 115: Petrozavodsk -> Severodvinsk (412.75km)
# step 116: Severodvinsk -> Arkhangelsk (33.55km)
# step 117: Arkhangelsk -> Murmansk (588.46km)
# step 118: Murmansk -> Kaliningrad (1712.77km)
# step 119: Kaliningrad -> Tambov (1393.76km)
# step 120: Tambov -> Sergiyev Posad (453.03km)
# step 121: Sergiyev Posad -> Ivanovo (191.44km)
# step 122: Ivanovo -> Kostroma (84.72km)
# step 123: Kostroma -> Yaroslavl (65.38km)
# step 124: Yaroslavl -> Rybinsk (78.17km)
# step 125: Rybinsk -> Cherepovets (131.90km)
# step 126: Cherepovets -> Vologda (114.80km)
# step 127: Vologda -> Kamyshin (1074.57km)
# step 128: Kamyshin -> Volzhskiy (152.69km)
# step 129: Volzhskiy -> Volgograd (23.11km)
# step 130: Volgograd -> Volgodonsk (218.86km)
# step 131: Volgodonsk -> Shakhty (147.54km)
# step 132: Shakhty -> Novoshakhtinsk (20.74km)
# step 133: Novoshakhtinsk -> Novocherkassk (38.39km)
# step 134: Novocherkassk -> Rostov‐na‐Donu (35.01km)
# step 135: Rostov‐na‐Donu -> Bataysk (11.52km)
# step 136: Bataysk -> Taganrog (64.29km)
# step 137: Taganrog -> Elista (416.91km)
# step 138: Elista -> Stavropol (225.14km)
# step 139: Stavropol -> Nevinnomyssk (45.59km)
# step 140: Nevinnomyssk -> Cherkessk (38.78km)
# step 141: Cherkessk -> Kislovodsk (67.64km)
# step 142: Kislovodsk -> Pyatigorsk (31.40km)
# step 143: Pyatigorsk -> Nalchik (75.94km)
# step 144: Nalchik -> Vladikavkaz (100.08km)
# step 145: Vladikavkaz -> Nazran (21.26km)
# step 146: Nazran -> Groznyy (73.92km)
# step 147: Groznyy -> Khasavyurt (72.55km)
# step 148: Khasavyurt -> Makhachkala (79.91km)
# step 149: Makhachkala -> Kaspiysk (15.94km)
# step 150: Kaspiysk -> Derbent (105.61km)
# step 151: Derbent -> Armavir (664.44km)
# step 152: Armavir -> Maykop (90.38km)
# step 153: Maykop -> Krasnodar (100.83km)
# step 154: Krasnodar -> Novorossiysk (101.63km)
# step 155: Novorossiysk -> Sochi (200.16km)
# step 156: Sochi -> Astrakhan (723.47km)
# step 157: Astrakhan -> Neftekamsk (1165.32km)
# step 158: Neftekamsk -> Izhevsk (107.05km)
# step 159: Izhevsk -> Nefteyugansk (1209.42km)
# step 160: Nefteyugansk -> Surgut (43.14km)
# step 161: Surgut -> Nizhnevartovsk (173.64km)
# step 162: Nizhnevartovsk -> Noyabrsk (254.53km)
# step 163: Noyabrsk -> Novyy Urengoy (328.30km)
# step 164: Novyy Urengoy -> Norilsk (612.52km)
# step 165: Norilsk -> Rubtsovsk (2018.47km)
# step 166: Rubtsovsk -> Kyzyl (911.80km)
# step 167: Kyzyl -> Abakan (299.57km)
#
# Result: Found a path of 167 steps, total length 44627.76km

# %% [markdown]
# ### Custom Nearest Neighbor Algorithm

# %%
# Custom Nearest Neighbor TSP algorithm with bidirectional expansion
def custom_nn_tsp(distance_matrix):
    num_cities = len(distance_matrix)
    visited = [False] * num_cities
    
    start_city = 0
    path = [start_city, start_city]
    visited[start_city] = True

    index = 0
    
    # Alternate adding the closest city from both ends towards the middle
    while not np.all(visited):
        # Expand from the front
        nearest_cities_front = np.argsort(distance_matrix[path[index]])
        nearest_to_front = next(
            city for city in nearest_cities_front if not visited[city]
        )
        path.insert(index + 1, nearest_to_front)  # Insert into next position
        visited[nearest_to_front] = True

        # Check if we filled all cities
        if np.all(visited):
            break

        # Expand from the back
        nearest_cities_back = np.argsort(distance_matrix[path[-(index+1)]])
        nearest_to_back = next(
            city for city in nearest_cities_back if not visited[city]
        )
        path.insert(-(index+1), nearest_to_back)  # Insert into next position
        visited[nearest_to_back] = True

        index += 1

    return path

# %% [markdown]
# #### Run Custom NNA

# %%
# Run custom NNA-based TSP algorithm
tsp_tour = custom_nn_tsp(DIST_MATRIX)
print("\nCustom Nearest Neighbor Algorithm TSP Tour\n")
print_tour(tsp_tour, DIST_MATRIX, CITIES)
# Out:
# Custom Nearest Neighbor Algorithm TSP Tour
#
# step 1: Abakan -> Krasnoyarsk (276.58km)
# step 2: Krasnoyarsk -> Achinsk (161.71km)
# step 3: Achinsk -> Kemerovo (296.59km)
# step 4: Kemerovo -> Tomsk (147.60km)
# step 5: Tomsk -> Seversk (14.97km)
# step 6: Seversk -> Biysk (454.70km)
# step 7: Biysk -> Kyzyl (636.95km)
# step 8: Kyzyl -> Angarsk (658.94km)
# step 9: Angarsk -> Irkutsk (34.88km)
# step 10: Irkutsk -> Ulan‐Ude (238.28km)
# step 11: Ulan‐Ude -> Chita (402.25km)
# step 12: Chita -> Bratsk (899.62km)
# step 13: Bratsk -> Nizhnevartovsk (1537.90km)
# step 14: Nizhnevartovsk -> Surgut (173.64km)
# step 15: Surgut -> Nefteyugansk (43.14km)
# step 16: Nefteyugansk -> Noyabrsk (278.28km)
# step 17: Noyabrsk -> Novyy Urengoy (328.30km)
# step 18: Novyy Urengoy -> Norilsk (612.52km)
# step 19: Norilsk -> Berezniki (1844.90km)
# step 20: Berezniki -> Izhevsk (353.17km)
# step 21: Izhevsk -> Naberezhnye Chelny (140.93km)
# step 22: Naberezhnye Chelny -> Almetyevsk (87.95km)
# step 23: Almetyevsk -> Dimitrovgrad (192.58km)
# step 24: Dimitrovgrad -> Ulyanovsk (75.41km)
# step 25: Ulyanovsk -> Tolyatti (119.47km)
# step 26: Tolyatti -> Novokuybyshevsk (49.80km)
# step 27: Novokuybyshevsk -> Samara (17.80km)
# step 28: Samara -> Syzran (112.35km)
# step 29: Syzran -> Balakovo (135.20km)
# step 30: Balakovo -> Engels (128.88km)
# step 31: Engels -> Saratov (9.98km)
# step 32: Saratov -> Kamyshin (169.44km)
# step 33: Kamyshin -> Volzhskiy (152.69km)
# step 34: Volzhskiy -> Volgograd (23.11km)
# step 35: Volgograd -> Volgodonsk (218.86km)
# step 36: Volgodonsk -> Shakhty (147.54km)
# step 37: Shakhty -> Novoshakhtinsk (20.74km)
# step 38: Novoshakhtinsk -> Novocherkassk (38.39km)
# step 39: Novocherkassk -> Rostov‐na‐Donu (35.01km)
# step 40: Rostov‐na‐Donu -> Bataysk (11.52km)
# step 41: Bataysk -> Taganrog (64.29km)
# step 42: Taganrog -> Krasnodar (243.49km)
# step 43: Krasnodar -> Maykop (100.83km)
# step 44: Maykop -> Armavir (90.38km)
# step 45: Armavir -> Stavropol (67.23km)
# step 46: Stavropol -> Nevinnomyssk (45.59km)
# step 47: Nevinnomyssk -> Cherkessk (38.78km)
# step 48: Cherkessk -> Kislovodsk (67.64km)
# step 49: Kislovodsk -> Pyatigorsk (31.40km)
# step 50: Pyatigorsk -> Nalchik (75.94km)
# step 51: Nalchik -> Vladikavkaz (100.08km)
# step 52: Vladikavkaz -> Nazran (21.26km)
# step 53: Nazran -> Groznyy (73.92km)
# step 54: Groznyy -> Khasavyurt (72.55km)
# step 55: Khasavyurt -> Makhachkala (79.91km)
# step 56: Makhachkala -> Kaspiysk (15.94km)
# step 57: Kaspiysk -> Derbent (105.61km)
# step 58: Derbent -> Astrakhan (477.07km)
# step 59: Astrakhan -> Elista (295.65km)
# step 60: Elista -> Sochi (464.97km)
# step 61: Sochi -> Novorossiysk (200.16km)
# step 62: Novorossiysk -> Belgorod (660.82km)
# step 63: Belgorod -> Staryy Oskol (116.64km)
# step 64: Staryy Oskol -> Voronezh (109.10km)
# step 65: Voronezh -> Lipetsk (103.13km)
# step 66: Lipetsk -> Yelets (75.22km)
# step 67: Yelets -> Oryol (169.03km)
# step 68: Oryol -> Bryansk (115.74km)
# step 69: Bryansk -> Kaluga (187.30km)
# step 70: Kaluga -> Smolensk (274.24km)
# step 71: Smolensk -> Velikie Luki (198.09km)
# step 72: Velikie Luki -> Pskov (212.88km)
# step 73: Pskov -> Velikiy Novgorod (189.82km)
# step 74: Velikiy Novgorod -> Kaliningrad (784.79km)
# step 75: Kaliningrad -> Kursk (1096.52km)
# step 76: Kursk -> Tambov (374.82km)
# step 77: Tambov -> Penza (245.48km)
# step 78: Penza -> Saransk (109.72km)
# step 79: Saransk -> Blagoveshchensk (5317.58km)
# step 80: Blagoveshchensk -> Khabarovsk (588.32km)
# step 81: Khabarovsk -> Komsomolsk‐na‐Amure (274.21km)
# step 82: Komsomolsk‐na‐Amure -> Ussuriysk (840.88km)
# step 83: Ussuriysk -> Artyom (50.78km)
# step 84: Artyom -> Vladivostok (34.21km)
# step 85: Vladivostok -> Nakhodka (87.36km)
# step 86: Nakhodka -> Yuzhno‐Sakhalinsk (901.85km)
# step 87: Yuzhno‐Sakhalinsk -> Petropavlovsk‐Kamchatskiy (1321.54km)
# step 88: Petropavlovsk‐Kamchatskiy -> Magadan (875.16km)
# step 89: Magadan -> Yakutsk (1173.79km)
# step 90: Yakutsk -> Kirov (4157.22km)
# step 91: Kirov -> Syktyvkar (347.95km)
# step 92: Syktyvkar -> Murmansk (1151.26km)
# step 93: Murmansk -> Arkhangelsk (588.46km)
# step 94: Arkhangelsk -> Severodvinsk (33.55km)
# step 95: Severodvinsk -> Kolpino (719.74km)
# step 96: Kolpino -> Saint Petersburg (25.47km)
# step 97: Saint Petersburg -> Petrozavodsk (302.88km)
# step 98: Petrozavodsk -> Cherepovets (358.19km)
# step 99: Cherepovets -> Vologda (114.80km)
# step 100: Vologda -> Ivanovo (254.39km)
# step 101: Ivanovo -> Kostroma (84.72km)
# step 102: Kostroma -> Yaroslavl (65.38km)
# step 103: Yaroslavl -> Rybinsk (78.17km)
# step 104: Rybinsk -> Tver (220.67km)
# step 105: Tver -> Sergiyev Posad (150.18km)
# step 106: Sergiyev Posad -> Kolomna (143.98km)
# step 107: Kolomna -> Ryazan (80.15km)
# step 108: Ryazan -> Novomoskovsk (115.09km)
# step 109: Novomoskovsk -> Tula (41.70km)
# step 110: Tula -> Serpukhov (81.18km)
# step 111: Serpukhov -> Obninsk (54.96km)
# step 112: Obninsk -> Odintsovo (76.71km)
# step 113: Odintsovo -> Podolsk (32.00km)
# step 114: Podolsk -> Zhukovskiy (47.16km)
# step 115: Zhukovskiy -> Lyubertsy (26.33km)
# step 116: Lyubertsy -> Moscow (19.17km)
# step 117: Moscow -> Zelenograd (29.58km)
# step 118: Zelenograd -> Khimki (10.91km)
# step 119: Khimki -> Mytishchi (18.28km)
# step 120: Mytishchi -> Korolyov (5.74km)
# step 121: Korolyov -> Shchyolkovo (12.70km)
# step 122: Shchyolkovo -> Balashikha (11.97km)
# step 123: Balashikha -> Zheleznodorozhnyy (6.96km)
# step 124: Zheleznodorozhnyy -> Elektrostal (26.94km)
# step 125: Elektrostal -> Noginsk (6.68km)
# step 126: Noginsk -> Orekhovo‐Zuevo (34.00km)
# step 127: Orekhovo‐Zuevo -> Vladimir (95.53km)
# step 128: Vladimir -> Kovrov (62.07km)
# step 129: Kovrov -> Murom (98.78km)
# step 130: Murom -> Arzamas (114.53km)
# step 131: Arzamas -> Dzerzhinsk (98.38km)
# step 132: Dzerzhinsk -> Nizhny Novgorod (34.91km)
# step 133: Nizhny Novgorod -> Yoshkar‐Ola (240.88km)
# step 134: Yoshkar‐Ola -> Cheboksary (68.49km)
# step 135: Cheboksary -> Novocheboksarsk (15.59km)
# step 136: Novocheboksarsk -> Kazan (109.88km)
# step 137: Kazan -> Magnitogorsk (686.26km)
# step 138: Magnitogorsk -> Orsk (247.00km)
# step 139: Orsk -> Novotroitsk (21.66km)
# step 140: Novotroitsk -> Orenburg (232.42km)
# step 141: Orenburg -> Orenberg (0.37km)
# step 142: Orenberg -> Salavat (185.10km)
# step 143: Salavat -> Sterlitamak (29.01km)
# step 144: Sterlitamak -> Ufa (128.14km)
# step 145: Ufa -> Oktyabrskiy (170.17km)
# step 146: Oktyabrskiy -> Nizhnekamsk (167.17km)
# step 147: Nizhnekamsk -> Neftekamsk (161.04km)
# step 148: Neftekamsk -> Perm (245.26km)
# step 149: Perm -> Nizhniy Tagil (220.37km)
# step 150: Nizhniy Tagil -> Kamensk‐Uralskiy (205.75km)
# step 151: Kamensk‐Uralskiy -> Yekaterinburg (95.20km)
# step 152: Yekaterinburg -> Pervouralsk (40.19km)
# step 153: Pervouralsk -> Zlatoust (194.64km)
# step 154: Zlatoust -> Miass (33.88km)
# step 155: Miass -> Chelyabinsk (87.20km)
# step 156: Chelyabinsk -> Kopeysk (14.72km)
# step 157: Kopeysk -> Kurgan (236.87km)
# step 158: Kurgan -> Tyumen (189.69km)
# step 159: Tyumen -> Tobolsk (200.98km)
# step 160: Tobolsk -> Omsk (475.40km)
# step 161: Omsk -> Rubtsovsk (647.47km)
# step 162: Rubtsovsk -> Barnaul (267.42km)
# step 163: Barnaul -> Novosibirsk (194.50km)
# step 164: Novosibirsk -> Leninsk‐Kuznetskiy (211.72km)
# step 165: Leninsk‐Kuznetskiy -> Prokopyevsk (91.87km)
# step 166: Prokopyevsk -> Novokuznetsk (30.63km)
# step 167: Novokuznetsk -> Abakan (285.72km)
#
# Result: Found a path of 167 steps, total length 46976.31km

# %% [markdown]
# ### Classic Nearest Neighbor Algorithm

# %%
def nearest_neighbor_tsp(distance_matrix):
    num_cities = len(distance_matrix)
    visited = np.zeros(num_cities, dtype=bool)  # Boolean array to track visited cities

    start_city = 0
    visited[start_city] = True
    path = [start_city]
    current_city = start_city

    for _ in range(num_cities - 1):
        # Find the nearest unvisited city 
        distances = distance_matrix[current_city]  # Get distances from current city
        nearest_cities = np.where(~visited)[0]  # Indices of unvisited cities
        
        # Find the nearest city among unvisited ones
        nearest_city_index = nearest_cities[np.argmin(distances[nearest_cities])]
        
        # Move to the nearest city
        path.append(nearest_city_index)
        visited[nearest_city_index] = True
        current_city = nearest_city_index

    # Return to the starting city to complete the tour
    path.append(start_city)

    return path

# %% [markdown]
# #### Run Classic NNA

# %%
# Run custom NN-based TSP algorithm
tsp_tour = nearest_neighbor_tsp(DIST_MATRIX)
print("\nClassical Nearest Neighbor Algorithm TSP Tour\n")
print_tour(tsp_tour, DIST_MATRIX, CITIES)
# Out:
# Classical Nearest Neighbor Algorithm TSP Tour
#
# step 1: Abakan -> Krasnoyarsk (276.58km)
# step 2: Krasnoyarsk -> Achinsk (161.71km)
# step 3: Achinsk -> Kemerovo (296.59km)
# step 4: Kemerovo -> Leninsk‐Kuznetskiy (74.76km)
# step 5: Leninsk‐Kuznetskiy -> Prokopyevsk (91.87km)
# step 6: Prokopyevsk -> Novokuznetsk (30.63km)
# step 7: Novokuznetsk -> Biysk (187.38km)
# step 8: Biysk -> Barnaul (132.82km)
# step 9: Barnaul -> Novosibirsk (194.50km)
# step 10: Novosibirsk -> Tomsk (206.90km)
# step 11: Tomsk -> Seversk (14.97km)
# step 12: Seversk -> Rubtsovsk (613.13km)
# step 13: Rubtsovsk -> Omsk (647.47km)
# step 14: Omsk -> Tobolsk (475.40km)
# step 15: Tobolsk -> Tyumen (200.98km)
# step 16: Tyumen -> Kurgan (189.69km)
# step 17: Kurgan -> Kopeysk (236.87km)
# step 18: Kopeysk -> Chelyabinsk (14.72km)
# step 19: Chelyabinsk -> Miass (87.20km)
# step 20: Miass -> Zlatoust (33.88km)
# step 21: Zlatoust -> Pervouralsk (194.64km)
# step 22: Pervouralsk -> Yekaterinburg (40.19km)
# step 23: Yekaterinburg -> Kamensk‐Uralskiy (95.20km)
# step 24: Kamensk‐Uralskiy -> Nizhniy Tagil (205.75km)
# step 25: Nizhniy Tagil -> Perm (220.37km)
# step 26: Perm -> Berezniki (159.92km)
# step 27: Berezniki -> Izhevsk (353.17km)
# step 28: Izhevsk -> Neftekamsk (107.05km)
# step 29: Neftekamsk -> Naberezhnye Chelny (129.52km)
# step 30: Naberezhnye Chelny -> Nizhnekamsk (31.95km)
# step 31: Nizhnekamsk -> Almetyevsk (88.07km)
# step 32: Almetyevsk -> Oktyabrskiy (88.27km)
# step 33: Oktyabrskiy -> Ufa (170.17km)
# step 34: Ufa -> Sterlitamak (128.14km)
# step 35: Sterlitamak -> Salavat (29.01km)
# step 36: Salavat -> Orenberg (185.10km)
# step 37: Orenberg -> Orenburg (0.37km)
# step 38: Orenburg -> Novotroitsk (232.42km)
# step 39: Novotroitsk -> Orsk (21.66km)
# step 40: Orsk -> Magnitogorsk (247.00km)
# step 41: Magnitogorsk -> Samara (588.03km)
# step 42: Samara -> Novokuybyshevsk (17.80km)
# step 43: Novokuybyshevsk -> Tolyatti (49.80km)
# step 44: Tolyatti -> Syzran (77.41km)
# step 45: Syzran -> Ulyanovsk (129.19km)
# step 46: Ulyanovsk -> Dimitrovgrad (75.41km)
# step 47: Dimitrovgrad -> Kazan (169.13km)
# step 48: Kazan -> Novocheboksarsk (109.88km)
# step 49: Novocheboksarsk -> Cheboksary (15.59km)
# step 50: Cheboksary -> Yoshkar‐Ola (68.49km)
# step 51: Yoshkar‐Ola -> Nizhny Novgorod (240.88km)
# step 52: Nizhny Novgorod -> Dzerzhinsk (34.91km)
# step 53: Dzerzhinsk -> Arzamas (98.38km)
# step 54: Arzamas -> Murom (114.53km)
# step 55: Murom -> Kovrov (98.78km)
# step 56: Kovrov -> Vladimir (62.07km)
# step 57: Vladimir -> Orekhovo‐Zuevo (95.53km)
# step 58: Orekhovo‐Zuevo -> Noginsk (34.00km)
# step 59: Noginsk -> Elektrostal (6.68km)
# step 60: Elektrostal -> Zheleznodorozhnyy (26.94km)
# step 61: Zheleznodorozhnyy -> Balashikha (6.96km)
# step 62: Balashikha -> Shchyolkovo (11.97km)
# step 63: Shchyolkovo -> Korolyov (12.70km)
# step 64: Korolyov -> Mytishchi (5.74km)
# step 65: Mytishchi -> Khimki (18.28km)
# step 66: Khimki -> Zelenograd (10.91km)
# step 67: Zelenograd -> Moscow (29.58km)
# step 68: Moscow -> Lyubertsy (19.17km)
# step 69: Lyubertsy -> Zhukovskiy (26.33km)
# step 70: Zhukovskiy -> Podolsk (47.16km)
# step 71: Podolsk -> Odintsovo (32.00km)
# step 72: Odintsovo -> Obninsk (76.71km)
# step 73: Obninsk -> Serpukhov (54.96km)
# step 74: Serpukhov -> Tula (81.18km)
# step 75: Tula -> Novomoskovsk (41.70km)
# step 76: Novomoskovsk -> Ryazan (115.09km)
# step 77: Ryazan -> Kolomna (80.15km)
# step 78: Kolomna -> Sergiyev Posad (143.98km)
# step 79: Sergiyev Posad -> Tver (150.18km)
# step 80: Tver -> Rybinsk (220.67km)
# step 81: Rybinsk -> Yaroslavl (78.17km)
# step 82: Yaroslavl -> Kostroma (65.38km)
# step 83: Kostroma -> Ivanovo (84.72km)
# step 84: Ivanovo -> Vologda (254.39km)
# step 85: Vologda -> Cherepovets (114.80km)
# step 86: Cherepovets -> Petrozavodsk (358.19km)
# step 87: Petrozavodsk -> Saint Petersburg (302.88km)
# step 88: Saint Petersburg -> Kolpino (25.47km)
# step 89: Kolpino -> Velikiy Novgorod (142.44km)
# step 90: Velikiy Novgorod -> Pskov (189.82km)
# step 91: Pskov -> Velikie Luki (212.88km)
# step 92: Velikie Luki -> Smolensk (198.09km)
# step 93: Smolensk -> Bryansk (230.10km)
# step 94: Bryansk -> Oryol (115.74km)
# step 95: Oryol -> Kursk (138.18km)
# step 96: Kursk -> Staryy Oskol (124.13km)
# step 97: Staryy Oskol -> Voronezh (109.10km)
# step 98: Voronezh -> Lipetsk (103.13km)
# step 99: Lipetsk -> Yelets (75.22km)
# step 100: Yelets -> Tambov (198.07km)
# step 101: Tambov -> Penza (245.48km)
# step 102: Penza -> Saransk (109.72km)
# step 103: Saransk -> Balakovo (295.88km)
# step 104: Balakovo -> Engels (128.88km)
# step 105: Engels -> Saratov (9.98km)
# step 106: Saratov -> Kamyshin (169.44km)
# step 107: Kamyshin -> Volzhskiy (152.69km)
# step 108: Volzhskiy -> Volgograd (23.11km)
# step 109: Volgograd -> Volgodonsk (218.86km)
# step 110: Volgodonsk -> Shakhty (147.54km)
# step 111: Shakhty -> Novoshakhtinsk (20.74km)
# step 112: Novoshakhtinsk -> Novocherkassk (38.39km)
# step 113: Novocherkassk -> Rostov‐na‐Donu (35.01km)
# step 114: Rostov‐na‐Donu -> Bataysk (11.52km)
# step 115: Bataysk -> Taganrog (64.29km)
# step 116: Taganrog -> Krasnodar (243.49km)
# step 117: Krasnodar -> Maykop (100.83km)
# step 118: Maykop -> Armavir (90.38km)
# step 119: Armavir -> Stavropol (67.23km)
# step 120: Stavropol -> Nevinnomyssk (45.59km)
# step 121: Nevinnomyssk -> Cherkessk (38.78km)
# step 122: Cherkessk -> Kislovodsk (67.64km)
# step 123: Kislovodsk -> Pyatigorsk (31.40km)
# step 124: Pyatigorsk -> Nalchik (75.94km)
# step 125: Nalchik -> Vladikavkaz (100.08km)
# step 126: Vladikavkaz -> Nazran (21.26km)
# step 127: Nazran -> Groznyy (73.92km)
# step 128: Groznyy -> Khasavyurt (72.55km)
# step 129: Khasavyurt -> Makhachkala (79.91km)
# step 130: Makhachkala -> Kaspiysk (15.94km)
# step 131: Kaspiysk -> Derbent (105.61km)
# step 132: Derbent -> Astrakhan (477.07km)
# step 133: Astrakhan -> Elista (295.65km)
# step 134: Elista -> Sochi (464.97km)
# step 135: Sochi -> Novorossiysk (200.16km)
# step 136: Novorossiysk -> Belgorod (660.82km)
# step 137: Belgorod -> Kaluga (437.86km)
# step 138: Kaluga -> Kirov (936.75km)
# step 139: Kirov -> Syktyvkar (347.95km)
# step 140: Syktyvkar -> Arkhangelsk (610.18km)
# step 141: Arkhangelsk -> Severodvinsk (33.55km)
# step 142: Severodvinsk -> Murmansk (572.02km)
# step 143: Murmansk -> Kaliningrad (1712.77km)
# step 144: Kaliningrad -> Nefteyugansk (3086.69km)
# step 145: Nefteyugansk -> Surgut (43.14km)
# step 146: Surgut -> Nizhnevartovsk (173.64km)
# step 147: Nizhnevartovsk -> Noyabrsk (254.53km)
# step 148: Noyabrsk -> Novyy Urengoy (328.30km)
# step 149: Novyy Urengoy -> Norilsk (612.52km)
# step 150: Norilsk -> Bratsk (1599.47km)
# step 151: Bratsk -> Angarsk (439.00km)
# step 152: Angarsk -> Irkutsk (34.88km)
# step 153: Irkutsk -> Ulan‐Ude (238.28km)
# step 154: Ulan‐Ude -> Chita (402.25km)
# step 155: Chita -> Blagoveshchensk (1002.31km)
# step 156: Blagoveshchensk -> Khabarovsk (588.32km)
# step 157: Khabarovsk -> Komsomolsk‐na‐Amure (274.21km)
# step 158: Komsomolsk‐na‐Amure -> Yuzhno‐Sakhalinsk (582.17km)
# step 159: Yuzhno‐Sakhalinsk -> Nakhodka (901.85km)
# step 160: Nakhodka -> Artyom (82.51km)
# step 161: Artyom -> Vladivostok (34.21km)
# step 162: Vladivostok -> Ussuriysk (74.97km)
# step 163: Ussuriysk -> Yakutsk (2034.16km)
# step 164: Yakutsk -> Magadan (1173.79km)
# step 165: Magadan -> Petropavlovsk‐Kamchatskiy (875.16km)
# step 166: Petropavlovsk‐Kamchatskiy -> Kyzyl (4230.63km)
# step 167: Kyzyl -> Abakan (299.57km)
#
# Result: Found a path of 167 steps, total length 42334.16km

# %% [markdown]
# ## Genetic Algorithms (GA)

# %% [markdown]
# #### Global code GA

# %%
@dataclass
class Individual:
    genome: list
    fitness: float = None

    def calculate_fitness(self):
        total_distance = 0
        for i in range(len(self.genome) - 1):
            total_distance += DIST_MATRIX[self.genome[i], self.genome[i + 1]]
        total_distance += DIST_MATRIX[self.genome[-1], self.genome[0]]  # Return to start
        self.fitness = 1/total_distance  # Fitness is inverse of distance --> note that -total_distance doesn't work with roulette wheel selection (due to negative values)

# %% [markdown]
# In the follow implementations of several parent selection, crossover and mutation strategies are proposed. Heuristically, it's possible to notice that the best approaches to use for the **Travelling Salesman Problem** are tournament selection along with order crossover (OX) and inversion mutation.

# %% [markdown]
# #### Parent Selection Strategies implementations

# %%
# Parent Selection Strategies
def uniform_selection(population):
    return random.choice(population)

def roulette_wheel_selection(population):
    total_fitness = sum(ind.fitness for ind in population)
    pick = random.uniform(0, total_fitness)
    current = 0
    for ind in population:
        current += ind.fitness
        if current > pick:
            return ind

def fitness_proportional_selection(population):
    fitnesses = np.array([ind.fitness for ind in population])
    probabilities = fitnesses / fitnesses.sum()
    return np.random.choice(population, p=probabilities)

def rank_based_selection(population):
    ranked_population = sorted(population, key=lambda ind: ind.fitness)
    ranks = np.arange(1, len(population) + 1)
    probabilities = ranks / ranks.sum()
    return np.random.choice(ranked_population, p=probabilities)

def tournament_selection(population, tournament_size=3):
    candidates = random.sample(population, tournament_size)
    return max(candidates, key=lambda ind: ind.fitness)

# %% [markdown]
# #### Crossover Strategies implementations

# %%
# Crossover Strategies
def order_crossover(parent1, parent2):
    size = len(parent1.genome)
    start, end = sorted(random.sample(range(1, size), 2))
    child_genome = [None] * size
    child_genome[start:end] = parent1.genome[start:end]
    
    current_index = 0
    for gene in parent2.genome:
        if gene not in child_genome:
            while child_genome[current_index] is not None:
                current_index += 1
            child_genome[current_index] = gene
            
    return Individual(genome=child_genome)

def partially_mapped_crossover(parent1, parent2):
    size = len(parent1.genome)
    start, end = sorted(random.sample(range(1, size), 2))
    
    child_genome1 = [None] * size
    child_genome2 = [None] * size

    # Create the mapping
    for i in range(start, end):
        child_genome1[i] = parent1.genome[i]
        child_genome2[i] = parent2.genome[i]

    mapping1 = {parent1.genome[i]: parent2.genome[i] for i in range(start, end)}
    mapping2 = {parent2.genome[i]: parent1.genome[i] for i in range(start, end)}

    # Fill in the rest
    for i in range(size):
        if child_genome1[i] is None:
            gene = parent2.genome[i]
            while gene in mapping2:
                gene = mapping2[gene]
            child_genome1[i] = gene

        if child_genome2[i] is None:
            gene = parent1.genome[i]
            while gene in mapping1:
                gene = mapping1[gene]
            child_genome2[i] = gene

    return Individual(genome=child_genome1), Individual(genome=child_genome2)

def cycle_crossover(parent1, parent2):
    size = len(parent1.genome)
    child_genome1 = [None] * size
    child_genome2 = [None] * size

    # Initialize the starting point
    cycle_start = 0
    while None in child_genome1:
        if child_genome1[cycle_start] is None:
            current = cycle_start
            while child_genome1[current] is None:
                child_genome1[current] = parent1.genome[current]
                current = parent2.genome.index(parent1.genome[current])
            # Fill child_genome2 with parent2 genes
            for i in range(size):
                if child_genome1[i] is None:
                    child_genome2[i] = parent2.genome[i]
    
    return Individual(genome=child_genome1), Individual(genome=child_genome2)

def inver_over_crossover(parent1, parent2):
    size = len(parent1.genome)
    start, end = sorted(random.sample(range(1, size), 2)) # Start from index 1 to avoid first city
    child_genome = parent1.genome[:start] + \
                   parent2.genome[start:end] + \
                   parent1.genome[end:]
    
    # Fix the child genome to ensure no cities are repeated
    child_genome = list(dict.fromkeys(child_genome))  # Remove duplicates while preserving order
    assert child_genome[0] == 0  # First city must be the starting city
    while len(child_genome) < size:
        for city in parent1.genome:
            if city not in child_genome:
                child_genome.append(city)
    return Individual(genome=child_genome)

# %% [markdown]
# #### Mutation Strategies implementations

# %%
# Mutation Strategies
def scramble_mutation(individual, mutation_rate=0.1):
    if np.random.rand() < mutation_rate:
        start, end = sorted(random.sample(range(1, len(individual.genome)), 2))
        segment = individual.genome[start:end]
        random.shuffle(segment)
        individual.genome[start:end] = segment
    return individual

def insert_mutation(individual, mutation_rate=0.1):
    if np.random.rand() < mutation_rate:
        idx1, idx2 = random.sample(range(1, len(individual.genome)), 2)
        gene = individual.genome.pop(idx1)
        individual.genome.insert(idx2, gene)
    return individual

def inversion_mutation(individual, mutation_rate=0.1):
    if np.random.rand() < mutation_rate:
        # Select two indices to invert
        idx1, idx2 = random.sample(range(1, len(individual.genome)), 2) #ensuring we don't choose index 0
        # Invert the section between the two indices
        if idx1 > idx2:
            idx1, idx2 = idx2, idx1
        individual.genome[idx1:idx2+1] = reversed(individual.genome[idx1:idx2+1])
    return individual

# %% [markdown]
# ### Genetic Algorithm implementation
# The algorithm is implemented in such a way as to allow choosing the parental selection, crossover and mutation strategies to be used.

# %%
# Main Genetic Algorithm for TSP
def genetic_algorithm_tsp(num_individuals=100, num_generations=1000,
                          parent_selection_strategy='tournament',
                          crossover_strategy='order',
                          mutation_strategy='inversion',
                          tournament_size=3, mutation_rate=0.1):
    
    # Initialize population with city 0 fixed and others randomly selected
    population = []
    for _ in range(num_individuals):
        unique_cities = random.sample(range(1, len(CITIES)), len(CITIES) - 1)
        genome = [0] + unique_cities  # Start with city 0
        population.append(Individual(genome=genome))

    #append the 3 greedy solutions (obtained previously) to the population to ensure that the good enough solution is not missed
    tour_greedy_1 = [int(i) for i in nearest_neighbor_tsp(DIST_MATRIX)]
    tour_greedy_1.pop()
    tour_greedy_2 = [int(i) for i in custom_nn_tsp(DIST_MATRIX)]
    tour_greedy_2.pop()
    tour_greedy_3 = [int(i) for i in mst_tsp(DIST_MATRIX)]
    tour_greedy_3.pop()
    population.append(Individual(genome=tour_greedy_1))
    population.append(Individual(genome=tour_greedy_2))
    population.append(Individual(genome=tour_greedy_3))

    # Evaluate initial population
    for ind in population:
        ind.calculate_fitness()

    for generation in range(num_generations):
        new_population = []

        while len(new_population) < num_individuals:

            # Select parents based on chosen strategy
            if parent_selection_strategy == 'uniform':
                parent1 = uniform_selection(population)
                parent2 = uniform_selection(population)
            elif parent_selection_strategy == 'roulette':
                parent1 = roulette_wheel_selection(population)
                parent2 = roulette_wheel_selection(population)
            elif parent_selection_strategy == 'fitness-proportional':
                parent1 = fitness_proportional_selection(population)
                parent2 = fitness_proportional_selection(population)
            elif parent_selection_strategy == 'rank':
                parent1 = rank_based_selection(population)
                parent2 = rank_based_selection(population)
            elif parent_selection_strategy == 'tournament':
                parent1 = tournament_selection(population, tournament_size)
                parent2 = tournament_selection(population, tournament_size)
            else:
                raise ValueError("Invalid parent selection strategy")

            # Crossover to create offspring based on chosen strategy
            if crossover_strategy == 'inver-over':
                child = inver_over_crossover(parent1, parent2)
            elif crossover_strategy == 'order':
                child = order_crossover(parent1, parent2)
            elif crossover_strategy == 'partially-mapped':
                child1, child2 = partially_mapped_crossover(parent1, parent2)
                child = child1 if np.random.rand() < 0.5 else child2
            elif crossover_strategy == 'cycle':
                child1, child2 = cycle_crossover(parent1, parent2)
                child = child1 if np.random.rand() < 0.5 else child2
            else:
                raise ValueError("Invalid crossover strategy")

            # Mutate offspring based on chosen strategy
            if mutation_strategy == 'scramble':
                child = scramble_mutation(child, mutation_rate)
            elif mutation_strategy == 'insert':
                child = insert_mutation(child, mutation_rate)
            elif mutation_strategy == 'inversion':
                child = inversion_mutation(child, mutation_rate)
            else:
                raise ValueError("Invalid mutation strategy")

            child.calculate_fitness()
            new_population.append(child)

        # Replace population with new population
        population = new_population

        # Print the best fitness at each generation
        best_fitness = max(ind.fitness for ind in population)
        if (generation + 1) % 100 == 0:
            print(f'Generation {generation + 1}: Current total distance = {1/best_fitness:.2f}km') 
            print(f'Best individual: {max(population, key=lambda ind: ind.fitness).genome}')

    # Return the best individual found
    best_individual = max(population, key=lambda ind: ind.fitness)
    return best_individual

# %% [markdown]
# #### Run the genetic algorithm, specifying the strategies

# %%
# Execute the Genetic Algorithm with specified strategies
best_solution = genetic_algorithm_tsp(
    num_individuals=100, 
    num_generations=4000,
    parent_selection_strategy='tournament',  # desired strategy among ['uniform', 'roulette', 'fitness-proportional', 'rank', 'tournament']
    crossover_strategy='order',                # desired strategy among ['inver-over', 'order', 'partially-mapped', 'cycle']
    mutation_strategy='inversion'              #  desired strategy among ['scramble', 'insert', 'inversion']
)


best_solution.genome.append(best_solution.genome[0])  # Return to starting city

print("\nGenetic Algorithm TSP Tour\n")
print_tour(best_solution.genome, DIST_MATRIX, CITIES)
# Out:
# Generation 100: Current total distance = 4559.43km
# Best individual: [0, 33, 12, 28, 25, 32, 6, 3, 20, 18, 22, 42, 13, 16, 10, 29, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 26, 39, 34, 15, 36, 7, 24, 37, 8, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 200: Current total distance = 4445.15km
# Best individual: [0, 33, 12, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 10, 29, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 26, 39, 34, 15, 36, 7, 24, 37, 8, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 300: Current total distance = 4328.94km
# Best individual: [0, 33, 12, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 400: Current total distance = 4328.94km
# Best individual: [0, 33, 12, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 500: Current total distance = 4328.94km
# Best individual: [0, 33, 12, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 600: Current total distance = 4328.94km
# Best individual: [0, 33, 12, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 700: Current total distance = 4328.94km
# Best individual: [0, 33, 12, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 800: Current total distance = 4328.94km
# Best individual: [0, 33, 12, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 900: Current total distance = 4328.94km
# Best individual: [0, 33, 12, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 1000: Current total distance = 4320.32km
# Best individual: [0, 33, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 1100: Current total distance = 4320.32km
# Best individual: [0, 33, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 1200: Current total distance = 4320.32km
# Best individual: [0, 33, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 1300: Current total distance = 4320.32km
# Best individual: [0, 33, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 1400: Current total distance = 4320.32km
# Best individual: [0, 33, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 1500: Current total distance = 4320.32km
# Best individual: [0, 33, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 1600: Current total distance = 4320.32km
# Best individual: [0, 33, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 1700: Current total distance = 4320.32km
# Best individual: [0, 33, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 1800: Current total distance = 4320.32km
# Best individual: [0, 33, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 1900: Current total distance = 4320.32km
# Best individual: [0, 33, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 2000: Current total distance = 4320.32km
# Best individual: [0, 33, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 2100: Current total distance = 4320.32km
# Best individual: [0, 33, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 2200: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 2300: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 2400: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 2500: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 2600: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 2700: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 2800: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 2900: Current total distance = 4311.91km
# Best individual: [0, 27, 14, 21, 35, 11, 1, 2, 38, 17, 31, 37, 8, 24, 7, 36, 15, 34, 39, 26, 12, 10, 29, 16, 13, 42, 22, 18, 20, 3, 6, 28, 25, 32, 19, 4, 9, 44, 40, 5, 45, 23, 43, 41, 30, 33]
# Generation 3000: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 3100: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 3200: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 3300: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 3400: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 3500: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 3600: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 3700: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 3800: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 3900: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
# Generation 4000: Current total distance = 4311.91km
# Best individual: [0, 33, 30, 41, 43, 23, 45, 5, 40, 44, 9, 4, 19, 32, 25, 28, 6, 3, 20, 18, 22, 42, 13, 16, 29, 10, 12, 26, 39, 34, 15, 36, 7, 24, 8, 37, 31, 17, 38, 2, 1, 11, 35, 21, 14, 27]
#
# Genetic Algorithm TSP Tour
#
# step 1: Ancona -> Rimini (90.60km)
# step 2: Rimini -> Ravenna (49.27km)
# step 3: Ravenna -> Trieste (183.83km)
# step 4: Trieste -> Venice (115.09km)
# step 5: Venice -> Padua (36.07km)
# step 6: Padua -> Vicenza (30.13km)
# step 7: Vicenza -> Bolzano (106.61km)
# step 8: Bolzano -> Trento (49.94km)
# step 9: Trento -> Verona (71.85km)
# step 10: Verona -> Ferrara (82.61km)
# step 11: Ferrara -> Bologna (43.43km)
# step 12: Bologna -> Modena (37.29km)
# step 13: Modena -> Reggio nell'Emilia (23.94km)
# step 14: Reggio nell'Emilia -> Parma (26.94km)
# step 15: Parma -> Piacenza (57.65km)
# step 16: Piacenza -> Brescia (68.99km)
# step 17: Brescia -> Bergamo (46.02km)
# step 18: Bergamo -> Monza (33.92km)
# step 19: Monza -> Milan (14.51km)
# step 20: Milan -> Novara (43.07km)
# step 21: Novara -> Turin (84.46km)
# step 22: Turin -> Genoa (123.19km)
# step 23: Genoa -> Leghorn (146.37km)
# step 24: Leghorn -> Prato (74.02km)
# step 25: Prato -> Florence (17.17km)
# step 26: Florence -> Forlì (80.03km)
# step 27: Forlì -> Perugia (126.70km)
# step 28: Perugia -> Terni (63.64km)
# step 29: Terni -> Rome (76.54km)
# step 30: Rome -> Latina (56.84km)
# step 31: Latina -> Sassari (372.88km)
# step 32: Sassari -> Cagliari (173.89km)
# step 33: Cagliari -> Palermo (390.28km)
# step 34: Palermo -> Catania (166.36km)
# step 35: Catania -> Syracuse (51.23km)
# step 36: Syracuse -> Reggio di Calabria (119.73km)
# step 37: Reggio di Calabria -> Messina (12.48km)
# step 38: Messina -> Taranto (293.02km)
# step 39: Taranto -> Bari (77.63km)
# step 40: Bari -> Andria (50.18km)
# step 41: Andria -> Foggia (67.42km)
# step 42: Foggia -> Salerno (109.52km)
# step 43: Salerno -> Naples (46.25km)
# step 44: Naples -> Giugliano in Campania (11.15km)
# step 45: Giugliano in Campania -> Pescara (169.94km)
# step 46: Pescara -> Ancona (139.24km)
#
# Result: Found a path of 46 steps, total length 4311.91km
